# %%
import pandas as pd
import numpy as np

# %%
transaction = pd.read_csv('transactions.csv',na_values='?', sep='|')
items = pd.read_csv('items.csv',na_values='?', sep='|')

# %%
transaction
# Out:
#         sessionID  itemID  click  basket  order
# 0               0   21310      1       0      0
# 1               1   73018      1       0      0
# 2               2   19194      1       0      0
# 3               3   40250      1       0      0
# 4               4   46107      1       0      0
# ...           ...     ...    ...     ...    ...
# 365138     279351   70183      1       0      0
# 365139     279352   39716      1       0      0
# 365140     279353   35260      1       0      0
# 365141     279353   18805      4       0      0
# 365142     279354    3083      1       0      0
#
# [365143 rows x 5 columns]

# %%
items
# Out:
#        itemID                                      title  \
# 0       21310             Princess Poppy: The Big Mix Up
# 1       73018             Einfach zeichnen! Step by Step
# 2       19194                                Red Queen 1
# 3       40250         Meine Kindergarten-Freunde (Pirat)
# 4       46107  Mein großes Schablonen-Buch - Wilde Tiere
# ...       ...                                        ...
# 78025   37678                       Timeless Fairy Tales
# 78026   68688                                Demon Games
# 78027   57291                    Lori and the Lion's Den
# 78028   78130                    The Everywhere Armchair
# 78029   68789                          The Light Voyager
#
#                                                   author  \
# 0                                     Janey Louise Jones
# 1                                          Wiebke Krabbe
# 2                                       Victoria Aveyard
# ...

# %%
#Create a list of columns to keep that are important
columns = ['title', 'authors', 'publisher']

# %%
#Create a new column with the combined features
items['combined_features'] = combine_features(items)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f4b516a80c4a> in <module>
#       1 #Create a new column with the combined features
# ----> 2 items['combined_features'] = combine_features(items)
#
# NameError: name 'combine_features' is not defined
